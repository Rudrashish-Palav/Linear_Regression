# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = 6 * np.random.rand(100,1) - 3 
y = 0.5 * x**2 + 1.5*x + 2 + np.random.randn(100,1)

plt.scatter(x,y, color = 'g')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.model_selection import train_test_split   
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
## Lets Implement a simple linear regression model
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, regression.predict(X_test))
print(score)
# Out:
# 0.6426180223534019

# %%
## Lets visualize the model 
plt.plot(X_train, regression.predict(X_train), color='blue')
plt.scatter(X_train, y_train, color='red')
plt.xlabel('X_dataset')
plt.ylabel('y_dataset')
# Out:
# Text(0, 0.5, 'y_dataset')

# %%
## Lets apply polynomial transformation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2,include_bias=True)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
X_train_poly
# Out:
# array([[ 1.00000000e+00,  2.00677865e+00,  4.02716055e+00],
#        [ 1.00000000e+00, -1.34911138e+00,  1.82010151e+00],
#        [ 1.00000000e+00,  2.32301543e+00,  5.39640070e+00],
#        [ 1.00000000e+00,  2.01349852e+00,  4.05417628e+00],
#        [ 1.00000000e+00,  2.01273895e+00,  4.05111809e+00],
#        [ 1.00000000e+00, -2.15826389e+00,  4.65810301e+00],
#        [ 1.00000000e+00,  5.48874354e-01,  3.01263056e-01],
#        [ 1.00000000e+00,  1.48145737e+00,  2.19471593e+00],
#        [ 1.00000000e+00, -1.29678440e+00,  1.68164979e+00],
#        [ 1.00000000e+00,  1.05475980e+00,  1.11251825e+00],
#        [ 1.00000000e+00,  2.30558713e+00,  5.31573200e+00],
#        [ 1.00000000e+00, -2.71878148e+00,  7.39177271e+00],
#        [ 1.00000000e+00, -2.27307134e+00,  5.16685333e+00],
#        [ 1.00000000e+00, -1.88141798e+00,  3.53973361e+00],
#        [ 1.00000000e+00, -2.94562281e+00,  8.67669375e+00],
#        [ 1.00000000e+00, -2.73213904e+00,  7.46458374e+00],
#        [ 1.00000000e+00, -2.80693139e+00,  7.87886382e+00],
#        [ 1.00000000e+00, -6.57137610e-01,  4.31829838e-01],
#        [ 1.00000000e+00, -1.52571344e+00,  2.32780150e+00],
#        [ 1.00000000e+00, -3.20695887e-01,  1.02845852e-01],
#        [ 1.00000000e+00,  5.77032219e-01,  3.32966182e-01],
#        [ 1.00000000e+00,  5.89383438e-01,  3.47372837e-01],
#        [ 1.00000000e+00,  9.91644099e-01,  9.83358018e-01],
#        [ 1.00000000e+00,  4.65688833e-01,  2.16866089e-01],
#        [ 1.00000000e+00,  2.56579749e+00,  6.58331674e+00],
#        [ 1.00000000e+00, -1.34338762e+00,  1.80469029e+00],
#        [ 1.00000000e+00, -2.73994150e+00,  7.50727945e+00],
#        [ 1.00000000e+00,  2.39049938e+00,  5.71448726e+00],
#        [ 1.00000000e+00, -2.13851783e+00,  4.57325851e+00],
#        [ 1.00000000e+00,  1.31735633e+00,  1.73542771e+00],
#        [ 1.00000000e+00,  1.67165681e+00,  2.79443648e+00],
#        [ 1.00000000e+00,  2.76797297e+00,  7.66167435e+00],
#        [ 1.00000000e+00, -7.82295243e-01,  6.11985847e-01],
#        [ 1.00000000e+00, -2.25403301e+00,  5.08066480e+00],
#        [ 1.00000000e+00,  1.22365552e+00,  1.49733284e+00],
#        [ 1.00000000e+00, -2.79060278e+00,  7.78746385e+00],
#        [ 1.00000000e+00,  9.06103743e-01,  8.21023993e-01],
#        [ 1.00000000e+00,  2.29018194e+00,  5.24493334e+00],
#        [ 1.00000000e+00,  2.47652221e+00,  6.13316228e+00],
#        [ 1.00000000e+00, -7.29648137e-01,  5.32386404e-01],
#        [ 1.00000000e+00, -2.82323718e-01,  7.97066820e-02],
#        [ 1.00000000e+00,  8.92635831e-01,  7.96798727e-01],
#        [ 1.00000000e+00,  6.99085419e-01,  4.88720423e-01],
#        [ 1.00000000e+00,  1.28945828e-01,  1.66270266e-02],
#        [ 1.00000000e+00, -2.91050036e+00,  8.47101236e+00],
#        [ 1.00000000e+00, -2.12743607e-01,  4.52598425e-02],
#        [ 1.00000000e+00, -2.46841261e+00,  6.09306081e+00],
#        [ 1.00000000e+00,  2.44069741e+00,  5.95700383e+00],
#        [ 1.00000000e+00,  2.37485045e+00,  5.63991464e+00],
#        [ 1.00000000e+00,  6.42803511e-02,  4.13196353e-03],
#        [ 1.00000000e+00, -1.79234855e+00,  3.21251333e+00],
#        [ 1.00000000e+00,  2.45362356e-01,  6.02026858e-02],
#        [ 1.00000000e+00,  8.94904623e-01,  8.00854285e-01],
#        [ 1.00000000e+00, -1.50577376e-01,  2.26735462e-02],
#        [ 1.00000000e+00, -1.27580242e+00,  1.62767181e+00],
#        [ 1.00000000e+00, -2.89565391e+00,  8.38481156e+00],
#        [ 1.00000000e+00,  2.51259561e+00,  6.31313670e+00],
#        [ 1.00000000e+00, -1.36645016e+00,  1.86718604e+00],
#        [ 1.00000000e+00,  1.01948246e+00,  1.03934449e+00],
#        [ 1.00000000e+00,  1.93572192e-01,  3.74701934e-02],
#        [ 1.00000000e+00,  2.55329642e+00,  6.51932259e+00],
#        [ 1.00000000e+00,  2.09425076e+00,  4.38588623e+00],
#        [ 1.00000000e+00,  1.76999195e+00,  3.13287151e+00],
#        [ 1.00000000e+00,  1.17605255e+00,  1.38309960e+00],
#        [ 1.00000000e+00,  2.76424047e+00,  7.64102539e+00],
#        [ 1.00000000e+00, -8.15977381e-01,  6.65819087e-01],
#        [ 1.00000000e+00,  2.27001990e+00,  5.15299033e+00],
#        [ 1.00000000e+00, -2.74324124e+00,  7.52537250e+00],
#        [ 1.00000000e+00,  2.99169299e+00,  8.95022692e+00],
#        [ 1.00000000e+00,  1.36064272e+00,  1.85134862e+00],
#        [ 1.00000000e+00, -5.37760684e-01,  2.89186553e-01],
#        [ 1.00000000e+00,  1.44076233e+00,  2.07579608e+00],
#        [ 1.00000000e+00, -1.31147403e+00,  1.71996413e+00],
#        [ 1.00000000e+00, -2.32702676e+00,  5.41505356e+00],
#        [ 1.00000000e+00,  1.10880964e+00,  1.22945881e+00],
#        [ 1.00000000e+00, -1.09390219e+00,  1.19662201e+00],
#        [ 1.00000000e+00, -2.97358136e+00,  8.84218610e+00],
#        [ 1.00000000e+00, -2.84535750e+00,  8.09605932e+00],
#        [ 1.00000000e+00,  1.30458313e+00,  1.70193713e+00],
#        [ 1.00000000e+00, -2.90370103e-01,  8.43147967e-02]])

# %%
regression = LinearRegression()
regression.fit(X_train_poly, y_train)
y_pred = regression.predict(X_test_poly)
score = r2_score(y_test, y_pred)
print("R-squared score:", score)
# Out:
# R-squared score: 0.8878868600819073

# %%
plt.scatter(X_train, regression.predict(X_train_poly), color='blue')
plt.scatter(X_train,y_train, color='red')
